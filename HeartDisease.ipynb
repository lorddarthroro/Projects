# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("/public/bmort/python/heart.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a9c5024e73fa> in <module>
# ----> 1 data = pd.read_csv("/public/bmort/python/heart.csv")
#
# NameError: name 'pd' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.describe()
# Out:
#               age         sex        pain          bp       chol       sugar  \
# count  300.000000  300.000000  300.000000  300.000000  300.00000  300.000000
# mean    54.480000    0.680000    3.153333  131.626667  246.93000    0.146667
# std      9.078049    0.467256    0.965884   17.687759   51.91798    0.354364
# min     29.000000    0.000000    1.000000   94.000000  126.00000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.00000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.50000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.25000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.00000    1.000000
#
#               ecg        rate      angina         stv         sts         mvn  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.986667  149.683333    0.326667    1.049667    1.603333    0.670000
# ...

# %%
from sklearn import preprocessing
names = ("age", "sex", "pain", "bp", "chol", "sugar", "ecg", "rate", "angina", "stv", "sts", "mvn", "thal", "disease")
age_array = np.array(data['age'])
normalized_arr = preprocessing.normalize([age_array])
pain_array = np.array(data['pain'])
normalized_arr = preprocessing.normalize([pain_array])

# %%
scaled_df = pd.DataFrame(normalized, columns = names)

# %%
scaled_df.describe()
# Out:
#               age         sex        pain          bp        chol       sugar  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.170009    0.002165    0.009888    0.409984    0.754239    0.000452
# std      0.033515    0.001517    0.003353    0.061691    0.067465    0.001102
# min      0.091624    0.000000    0.002614    0.191274    0.470831    0.000000
# 25%      0.143668    0.000000    0.007338    0.368252    0.711954    0.000000
# 50%      0.169857    0.002972    0.010269    0.403958    0.755066    0.000000
# 75%      0.192058    0.003254    0.012398    0.454463    0.803373    0.000000
# max      0.301534    0.004445    0.017781    0.621993    0.938076    0.004120
#
#               ecg        rate      angina         stv         sts         mvn  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.003026    0.466482    0.001028    0.003297    0.005042    0.002067
# ...

# %%
import sklearn as sk
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2)

# %%
from sklearn import svm
disease = np.array(train['disease'])
clf = svm.LinearSVC()
clf.fit(train, disease)
# Out:
# /software/anaconda3/2019.03/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
predict = clf.predict(test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test['disease'], predict)
# Out:
# array([[26,  3],
#        [ 5, 26]])
